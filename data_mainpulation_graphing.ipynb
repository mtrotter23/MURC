# %%
import pandas as pd 
import altair as alt

# %%
bear = pd.read_csv('bb.csv')

van_island=pd.read_csv('van_islandclimate-daily.csv', low_memory=False)

precip_vi = van_island[['LOCAL_YEAR', 'LOCAL_DAY', 'LOCAL_MONTH', 'TOTAL_PRECIPITATION', 'TOTAL_RAIN', 'TOTAL_SNOW']].dropna()
temp_vi =van_island[['LOCAL_YEAR', 'LOCAL_DAY', 'LOCAL_MONTH', 'MAX_TEMPERATURE', 'MEAN_TEMPERATURE', 'MIN_TEMPERATURE']].dropna()
display(temp_vi, precip_vi)
# Out:
#         LOCAL_YEAR  LOCAL_DAY  LOCAL_MONTH  MAX_TEMPERATURE  MEAN_TEMPERATURE  \
# 1075          2013         17            4             10.1               8.5
# 1076          2013         18            4              9.0               7.4
# 1077          2013         19            4             10.4               9.1
# 1078          2013         20            4              9.3               8.4
# 1079          2013         21            4              9.3               7.8
# ...            ...        ...          ...              ...               ...
# 149995        2021          4            6             15.8              12.7
# 149996        2021          5            6             14.9              11.8
# 149997        2021          6            6             14.7              11.5
# 149998        2021          7            6             14.5               9.9
# 149999        2021          8            6             12.9              10.2
#
#         MIN_TEMPERATURE
# ...

# %%
# Out:
#         month  year  calls_received
# 0     January  2023             131
# 1     January  2022             156
# 2     January  2021             100
# 3     January  2020             190
# 4     January  2019             115
# ..        ...   ...             ...
# 148  December  2015             471
# 149  December  2014             229
# 150  December  2013             382
# 151  December  2012             336
# 152  December  2011             576
#
# [153 rows x 3 columns]
