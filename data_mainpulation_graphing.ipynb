# %% [markdown]
# #

# %%
import pandas as pd 
import altair as alt 
from sklearn.compose import make_column_transformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.metrics.pairwise import euclidean_distances
from sklearn import set_config
from sklearn.preprocessing import StandardScaler

# %%
#reading in data
bear = pd.read_csv('bb.csv')

#weather on Vancouver Island as a Whole
van_island=pd.read_csv('van_islandclimate-daily.csv', low_memory=False)
#weather in BC ass a whole 
bc = bc = pd.read_csv('BC_climate_daily.csv', low_memory=False)

van_island['LOCAL_MONTH'] = van_island['LOCAL_MONTH'].replace({
    1 : "January", 
    2 : 'Febuary',
    3 : 'March',
    4 : 'April',
    5: 'May',
    6 : 'June', 
    7 : 'July',
    8 : 'Augsust', 
    9 : 'September',
    10: 'October',
    11: 'November',
    12: 'December'
})

bc['LOCAL_MONTH'] = bc['LOCAL_MONTH'].replace({
    1 : "January", 
    2 : 'Febuary',
    3 : 'March',
    4 : 'April',
    5: 'May',
    6 : 'June', 
    7 : 'July',
    8 : 'Augsust', 
    9 : 'September',
    10: 'October',
    11: 'November',
    12: 'December'
})

#filter each data set out year, 
#group they by 'LOCAL_MONTH', with mean
#pd.concat them all together 
#compare all the weather patterns to see the relationship between them all. -> aprove of trend hopefully!!

# %%
precip_vi = van_island[['LOCAL_YEAR', 'LOCAL_DAY', 'LOCAL_MONTH', 'TOTAL_PRECIPITATION', 'TOTAL_RAIN', 'TOTAL_SNOW']].dropna()
precip_bc = bc[['LOCAL_YEAR', 'LOCAL_DAY', 'LOCAL_MONTH', 'TOTAL_PRECIPITATION', 'TOTAL_RAIN', 'TOTAL_SNOW']].dropna()

precip_vi_2011 = precip_vi[precip_vi['LOCAL_YEAR']==2011].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
precip_vi_2012 = precip_vi[precip_vi['LOCAL_YEAR']==2012].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
precip_vi_2013 = precip_vi[precip_vi['LOCAL_YEAR']==2013].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
precip_vi_2014 = precip_vi[precip_vi['LOCAL_YEAR']==2014].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
precip_vi_2015 = precip_vi[precip_vi['LOCAL_YEAR']==2015].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
precip_vi_2016 = precip_vi[precip_vi['LOCAL_YEAR']==2016].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
precip_vi_2017 = precip_vi[precip_vi['LOCAL_YEAR']==2017].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
precip_vi_2018 = precip_vi[precip_vi['LOCAL_YEAR']==2018].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
precip_vi_2019 = precip_vi[precip_vi['LOCAL_YEAR']==2019].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
precip_vi_2020 = precip_vi[precip_vi['LOCAL_YEAR']==2020].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
precip_vi_2021 = precip_vi[precip_vi['LOCAL_YEAR']==2021].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
precip_vi_2022 = precip_vi[precip_vi['LOCAL_YEAR']==2022].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
precip_vi_2023 = precip_vi[precip_vi['LOCAL_YEAR']==2023].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
#precip_vi_2024 = precip_vi[precip_vi['LOCAL_YEAR']==2024].groupby('LOCAL_YEAR').mean(numeric_only=True).reset_index().assign(region = 'VI')

precip_vi_month=pd.concat([precip_vi_2011,
                       precip_vi_2012, 
                       precip_vi_2013,
                       precip_vi_2014,
                       precip_vi_2015,
                       precip_vi_2016,
                       precip_vi_2017,
                       precip_vi_2018,
                       precip_vi_2019,
                       precip_vi_2020,
                       precip_vi_2021,
                       precip_vi_2022,
                       precip_vi_2023
                       ], ignore_index=True, axis=0)

precip_bc_2011 = precip_bc[precip_bc['LOCAL_YEAR']==2011].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
precip_bc_2012 = precip_bc[precip_bc['LOCAL_YEAR']==2012].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
precip_bc_2013 = precip_bc[precip_bc['LOCAL_YEAR']==2013].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
precip_bc_2014 = precip_bc[precip_bc['LOCAL_YEAR']==2014].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
precip_bc_2015 = precip_bc[precip_bc['LOCAL_YEAR']==2015].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
precip_bc_2016 = precip_bc[precip_bc['LOCAL_YEAR']==2016].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
precip_bc_2017 = precip_bc[precip_bc['LOCAL_YEAR']==2017].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
precip_bc_2018 = precip_bc[precip_bc['LOCAL_YEAR']==2018].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
precip_bc_2019 = precip_bc[precip_bc['LOCAL_YEAR']==2019].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
precip_bc_2020 = precip_bc[precip_bc['LOCAL_YEAR']==2020].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
precip_bc_2021 = precip_bc[precip_bc['LOCAL_YEAR']==2021].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
precip_bc_2022 = precip_bc[precip_bc['LOCAL_YEAR']==2022].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
precip_bc_2023 = precip_bc[precip_bc['LOCAL_YEAR']==2023].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
#precip_bc_2024 = precip_bc[precip_bc['LOCAL_YEAR']==2024].groupby('LOCAL_YEAR').mean(numeric_only=True).reset_index().assign(region = 'BC')

precip_bc_month= pd.concat([precip_bc_2011,
                            precip_bc_2012,
                            precip_bc_2013,
                            precip_bc_2014,
                            precip_bc_2015,
                            precip_bc_2016,
                            precip_bc_2017,
                            precip_bc_2018,
                            precip_bc_2019,
                            precip_bc_2020,
                            precip_bc_2021,
                            precip_bc_2022,
                            precip_bc_2023], ignore_index=True, axis=0)

precip_both = pd.concat([precip_bc_month, precip_vi_month], ignore_index=True, axis=0)
compare_precip_both =alt.Chart(precip_both).mark_line().encode(
    x=alt.X('LOCAL_MONTH').title('Month').scale(zero=False),
    y=alt.Y('TOTAL_PRECIPITATION').title('Total Precipitation').scale(zero=False),
    color='region'
).facet('LOCAL_YEAR', columns = 5)
#shows simillar trend in weather patterns between vancouver island and bc, thus can make similar trends in how Vancouver island 
compare_precip_both
# Out:
# alt.FacetChart(...)

# %%
# Out:
#    LOCAL_MONTH  LOCAL_YEAR  LOCAL_DAY  TOTAL_PRECIPITATION  TOTAL_RAIN  \
# 0        April      2015.0  15.393360             0.669819    0.571328
# 1      Augsust      2015.0  15.952709             1.124335    1.124138
# 2     December      2015.0  15.794651             3.104776    1.366858
# 3      Febuary      2015.0  14.489130             1.760573    1.255138
# 4      January      2015.0  16.008152             2.151993    0.382065
# 5         July      2015.0  16.037182             1.093640    1.093640
# 6         June      2015.0  15.413198             1.910863    1.910863
# 7        March      2015.0  15.899471             2.020723    1.752293
# 8          May      2015.0  16.175403             1.337198    1.331149
# 9     November      2015.0  15.538316             2.973037    1.962346
# 10     October      2015.0  16.059048             1.736095    1.735714
# 11   September      2015.0  15.378631             1.637033    1.634959
#
#     TOTAL_SNOW region
# ...

# %%
#standaizing bc_temp data 
precip_bc_month['LOCAL_MONTH'] = precip_bc_month['LOCAL_MONTH'].astype('str')
precip_bc_month['LOCAL_YEAR'] = precip_bc_month['LOCAL_YEAR'].astype('str')
precip_bc_month['LOCAL_DAY'] = precip_bc_month['LOCAL_DAY'].astype('str')

preprocessor = make_column_transformer(
    (StandardScaler(), make_column_selector(dtype_include="number")),
    remainder="passthrough",
    verbose_feature_names_out=False)

preprocessor.fit(precip_bc_month)

scaled_bc_precip = pd.DataFrame(preprocessor.transform(precip_bc_month)).rename(columns = {
    0 : 'tot_precip',
    1 : 'tot_rain',
    2: 'tot_snow',
    3: 'month',
    4: 'year',
    5: 'day', 
    6: 'region' })

bear['month'] = bear['month'].astype('str')
bear['year'] = bear['year'].astype('str')

preprocessor_2=preprocessor.fit(bear)

scaled_bear = pd.DataFrame(preprocessor_2.transform(bear)).rename(columns = {
    0: 'calls_received', 
    1: 'month', 
    2: 'year'
})                                   
scaled_bear['calls_received'] = scaled_bear['calls_received'].astype('int')
bear_year = scaled_bear.groupby('year').mean(numeric_only=True).reset_index()

scaled_bc_precip['tot_precip'] = scaled_bc_precip['tot_precip'].astype('int')
bc_precip_year = scaled_bc_precip.groupby('year').mean(numeric_only=True).reset_index()
bc_precip_year['year'] = bc_precip_year['year'].astype('str').replace({
    '2011.0' : '2011', 
    '2012.0' : '2012',
    '2013.0' : '2013',
    '2014.0' : '2014',
    '2015.0' : '2015',
    '2016.0' : '2016',
    '2017.0' : '2017',
    '2018.0' : '2018',
    '2019.0' : '2019',
    '2020.0' : '2020',
    '2021.0' : '2021',
    '2022.0' : '2022',
    '2023.0' : '2023'})
bear_plot = alt.Chart(bear_year).mark_line(color='green').encode(
    x=alt.X('year:T').title('Year'), 
    y=alt.Y('calls_received').title('Calls Recevied')
)

bc_precip_plot =alt.Chart(bc_precip_year, title = 'Total Precipation and Calls Received per Year').mark_bar(color='blue').encode(
    x=alt.X('year:T').scale(zero=False),
    y=alt.Y('tot_precip').title('Total Precipitation').scale(zero=False),
)

temp_precip_plot = bear_plot+bc_precip_plot
temp_precip_plot
# Out:
# alt.LayerChart(...)

# %%
temp_vi =van_island[['LOCAL_YEAR', 'LOCAL_DAY', 'LOCAL_MONTH', 'MAX_TEMPERATURE', 'MEAN_TEMPERATURE', 'MIN_TEMPERATURE']].dropna()
temp_bc= bc[['LOCAL_YEAR', 'LOCAL_DAY', 'LOCAL_MONTH', 'MAX_TEMPERATURE', 'MEAN_TEMPERATURE', 'MIN_TEMPERATURE']].dropna()

temp_vi_2011 = temp_vi[temp_vi['LOCAL_YEAR']==2011].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
temp_vi_2012 = temp_vi[temp_vi['LOCAL_YEAR']==2012].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
temp_vi_2013 = temp_vi[temp_vi['LOCAL_YEAR']==2013].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
temp_vi_2014 = temp_vi[temp_vi['LOCAL_YEAR']==2014].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
temp_vi_2015 = temp_vi[temp_vi['LOCAL_YEAR']==2015].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
temp_vi_2016 = temp_vi[temp_vi['LOCAL_YEAR']==2016].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
temp_vi_2017 = temp_vi[temp_vi['LOCAL_YEAR']==2017].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
temp_vi_2018 = temp_vi[temp_vi['LOCAL_YEAR']==2018].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
temp_vi_2019 = temp_vi[temp_vi['LOCAL_YEAR']==2019].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
temp_vi_2020 = temp_vi[temp_vi['LOCAL_YEAR']==2020].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
temp_vi_2021 = temp_vi[temp_vi['LOCAL_YEAR']==2021].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
temp_vi_2022 = temp_vi[temp_vi['LOCAL_YEAR']==2022].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
temp_vi_2023 = temp_vi[temp_vi['LOCAL_YEAR']==2023].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'VI')
#temp_vi_2024 = temp_vi[temp_vi['LOCAL_YEAR']==2024].groupby('LOCAL_YEAR').mean(numeric_only=True).reset_index().assign(region = 'VI')

temp_vi_month = pd.concat([temp_vi_2011,
                          temp_vi_2012,
                          temp_vi_2013,
                          temp_vi_2014,
                          temp_vi_2015,
                          temp_vi_2016,
                          temp_vi_2017,
                          temp_vi_2018,
                          temp_vi_2019,
                          temp_vi_2020,
                          temp_vi_2021,
                          temp_vi_2022,
                          temp_vi_2023], ignore_index=True, axis=0)

temp_bc_2011 = temp_bc[temp_bc['LOCAL_YEAR']==2011].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
temp_bc_2012 = temp_bc[temp_bc['LOCAL_YEAR']==2012].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
temp_bc_2013 = temp_bc[temp_bc['LOCAL_YEAR']==2013].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
temp_bc_2014 = temp_bc[temp_bc['LOCAL_YEAR']==2014].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
temp_bc_2015 = temp_bc[temp_bc['LOCAL_YEAR']==2015].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
temp_bc_2016 = temp_bc[temp_bc['LOCAL_YEAR']==2016].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
temp_bc_2017 = temp_bc[temp_bc['LOCAL_YEAR']==2017].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
temp_bc_2018 = temp_bc[temp_bc['LOCAL_YEAR']==2018].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
temp_bc_2019 = temp_bc[temp_bc['LOCAL_YEAR']==2019].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
temp_bc_2020 = temp_bc[temp_bc['LOCAL_YEAR']==2020].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
temp_bc_2021 = temp_bc[temp_bc['LOCAL_YEAR']==2021].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
temp_bc_2022 = temp_bc[temp_bc['LOCAL_YEAR']==2022].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
temp_bc_2023 = temp_bc[temp_bc['LOCAL_YEAR']==2023].groupby('LOCAL_MONTH').mean(numeric_only=True).reset_index().assign(region = 'BC')
#temp_bc_2024 = temp_bc[temp_bc['LOCAL_YEAR']==2024].groupby('LOCAL_YEAR').mean(numeric_only=True).reset_index().assign(region = 'BC')

temp_bc_month = pd.concat([temp_bc_2011,
                          temp_bc_2012,
                          temp_bc_2013,
                          temp_bc_2014,
                          temp_bc_2015,
                          temp_bc_2016,
                          temp_bc_2017,
                          temp_bc_2018,
                          temp_bc_2019,
                          temp_bc_2020,
                          temp_bc_2021,
                          temp_bc_2022,
                          temp_bc_2023], ignore_index=True, axis=0)

temp_both = pd.concat([temp_bc_month, temp_vi_month], ignore_index=True, axis=0)

compare_temp_plot = alt.Chart(temp_both, title = 'Mean Temperatures of Vanoucer Island (VI) and British Columbia (BC)').mark_line().encode(
    x=alt.X('LOCAL_MONTH').scale(zero=False).title('Month'),
    y=alt.Y('MEAN_TEMPERATURE').scale(zero=False).title('Mean Temperatures in Degrees Celcius'),
    color='region'
).facet('LOCAL_YEAR', columns = 5)
compare_temp_plot
# Out:
# alt.FacetChart(...)

# %%
#standaizing bc_temp data 
temp_bc_month['LOCAL_MONTH'] = temp_bc_month['LOCAL_MONTH'].astype('str')
temp_bc_month['LOCAL_YEAR'] = temp_bc_month['LOCAL_YEAR'].astype('str')
temp_bc_month['LOCAL_DAY'] = temp_bc_month['LOCAL_DAY'].astype('str')

preprocessor = make_column_transformer(
    (StandardScaler(), make_column_selector(dtype_include="number")),
    remainder="passthrough",
    verbose_feature_names_out=False)

preprocessor.fit(temp_bc_month)

scaled_bc_temp = pd.DataFrame(preprocessor.transform(temp_bc_month)).rename(columns = {
    0 : 'max_temp',
    1 : 'mean_temp',
    2: 'min_temp',
    3: 'month',
    4: 'year',
    5: 'day', 
    6: 'region' })
                                        

#standadizing bear data 
bear['month'] = bear['month'].astype('str')
bear['year'] = bear['year'].astype('str')

preprocessor_2=preprocessor.fit(bear)

scaled_bear = pd.DataFrame(preprocessor_2.transform(bear)).rename(columns = {
    0: 'calls_received', 
    1: 'month', 
    2: 'year'
})

scaled_bear['calls_received'] = scaled_bear['calls_received'].astype('int')
bear_year = scaled_bear.groupby('year').mean(numeric_only=True).reset_index()

scaled_bc_temp['mean_temp'] = scaled_bc_temp['mean_temp'].astype('int')
bc_temp_year = scaled_bc_temp.groupby('year').mean(numeric_only=True).reset_index()
bc_temp_year['year'] = bc_temp_year['year'].astype('str').replace({
    '2011.0' : '2011', 
    '2012.0' : '2012',
    '2013.0' : '2013',
    '2014.0' : '2014',
    '2015.0' : '2015',
    '2016.0' : '2016',
    '2017.0' : '2017',
    '2018.0' : '2018',
    '2019.0' : '2019',
    '2020.0' : '2020',
    '2021.0' : '2021',
    '2022.0' : '2022',
    '2023.0' : '2023'})
bear_plot = alt.Chart(bear_year).mark_line(color='green').encode(
    x=alt.X('year:T').title('Year'), 
    y=alt.Y('calls_received').title('Calls Recevied')
)

bc_temp_plot =alt.Chart(bc_temp_year, title = 'Mean Tempeature and Calls Received per Year').mark_line(color='red').encode(
    x=alt.X('year:T').scale(zero=False),
    y=alt.Y('mean_temp').title('Mean Temperture in Degrees Celcuis').scale(zero=False),
)

#temp_bear_plot = alt.HConcatChart(bc_temp_plot, bear_plot)
temp_bear_plot = bear_plot+bc_temp_plot
temp_bear_plot

temp_bear_precip_plot = bear_plot+bc_temp_plot+bc_precip_plot
temp_bear_precip_plot
temp_bear_plot
# Out:
# alt.LayerChart(...)

# %%
scaled_temp_bc_2011 = scaled_bc_temp[scaled_bc_temp['year']=='2011.0']
scaled_temp_bc_2012 = scaled_bc_temp[scaled_bc_temp['year']=='2012.0']
scaled_temp_bc_2013 = scaled_bc_temp[scaled_bc_temp['year']=='2013.0']
scaled_temp_bc_2014 = scaled_bc_temp[scaled_bc_temp['year']=='2014.0']
scaled_temp_bc_2015 = scaled_bc_temp[scaled_bc_temp['year']=='2015.0']
scaled_temp_bc_2016 = scaled_bc_temp[scaled_bc_temp['year']=='2016.0']
scaled_temp_bc_2017 = scaled_bc_temp[scaled_bc_temp['year']=='2017.0']
scaled_temp_bc_2018 = scaled_bc_temp[scaled_bc_temp['year']=='2018.0']
scaled_temp_bc_2019 = scaled_bc_temp[scaled_bc_temp['year']=='2019.0']
scaled_temp_bc_2020 = scaled_bc_temp[scaled_bc_temp['year']=='2020.0']
scaled_temp_bc_2021 = scaled_bc_temp[scaled_bc_temp['year']=='2021.0']
scaled_temp_bc_2022 = scaled_bc_temp[scaled_bc_temp['year']=='2022.0']
scaled_temp_bc_2023 = scaled_bc_temp[scaled_bc_temp['year']=='2023.0']

scaled_bear_2011 = scaled_bear[scaled_bear['year'] =='2011']
scaled_bear_2012 = scaled_bear[scaled_bear['year'] =='2012']
scaled_bear_2013 = scaled_bear[scaled_bear['year'] =='2013']
scaled_bear_2014 = scaled_bear[scaled_bear['year'] =='2014']
scaled_bear_2015 = scaled_bear[scaled_bear['year'] =='2015']
scaled_bear_2016 = scaled_bear[scaled_bear['year'] =='2016']
scaled_bear_2017 = scaled_bear[scaled_bear['year'] =='2017']
scaled_bear_2018 = scaled_bear[scaled_bear['year'] =='2018']
scaled_bear_2019 = scaled_bear[scaled_bear['year'] =='2019']
scaled_bear_2020 = scaled_bear[scaled_bear['year'] =='2020']
scaled_bear_2021 = scaled_bear[scaled_bear['year'] =='2021']
scaled_bear_2022 = scaled_bear[scaled_bear['year'] =='2022']
scaled_bear_2023 = scaled_bear[scaled_bear['year'] =='2023']

temp_2011 = alt.Chart(scaled_temp_bc_2011).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('mean_temp').title('Mean Temperature in degrees Celcuis'),
    color =alt.value("#FFAA00")
)
bear_2011 = alt.Chart(scaled_bear_2011).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('calls_received').title('Calls Received')
)
plot_2011 = alt.layer(temp_2011, bear_2011)
#2012 
temp_2012 = alt.Chart(scaled_temp_bc_2012).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('mean_temp').title('Mean Temperature in degrees Celcuis'),
    color =alt.value("#FFAA00")
)
bear_2012 = alt.Chart(scaled_bear_2012).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('calls_received').title('Calls Received')
)
plot_2012 = alt.layer(temp_2012, bear_2012)
#2013
temp_2013 = alt.Chart(scaled_temp_bc_2013).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('mean_temp').title('Mean Temperature in degrees Celcuis'),
    color =alt.value("#FFAA00")
)
bear_2013 = alt.Chart(scaled_bear_2013).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('calls_received').title('Calls Received')
)
plot_2013 = alt.layer(temp_2013, bear_2013)
temp_2014 = alt.Chart(scaled_temp_bc_2014).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('mean_temp').title('Mean Temperature in degrees Celcuis'),
    color =alt.value("#FFAA00")
)
bear_2014 = alt.Chart(scaled_bear_2014).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('calls_received').title('Calls Received')
)
plot_2014 = alt.layer(temp_2014, bear_2014)
#2015
temp_2015 = alt.Chart(scaled_temp_bc_2015).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('mean_temp').title('Mean Temperature in degrees Celcuis'),
    color =alt.value("#FFAA00")
)
bear_2015 = alt.Chart(scaled_bear_2015).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('calls_received').title('Calls Received')
)
plot_2015 = alt.layer(temp_2015, bear_2015)
#2016 
temp_2016 = alt.Chart(scaled_temp_bc_2016).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('mean_temp').title('Mean Temperature in degrees Celcuis'),
    color =alt.value("#FFAA00")
)
bear_2016 = alt.Chart(scaled_bear_2016).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('calls_received').title('Calls Received')
)
plot_2016 = alt.layer(temp_2016, bear_2016)
#2017 
temp_2017 = alt.Chart(scaled_temp_bc_2017).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('mean_temp').title('Mean Temperature in degrees Celcuis'),
    color =alt.value("#FFAA00")
)
bear_2017 = alt.Chart(scaled_bear_2017).mark_line().encode(
    x=alt.X('month').title('Month'),
    y=alt.Y('calls_received').title('Calls Received')
)
plot_2017 = alt.layer(temp_2017, bear_2017)
#2018
display(plot_2011, plot_2012, plot_2013, plot_2014, plot_2014)
# Out:
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
